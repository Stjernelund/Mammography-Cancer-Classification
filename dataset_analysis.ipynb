# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
meta_dir = "./data/metadata"
dicom_data = pd.read_csv(meta_dir + '/dicom_info.csv')
train_csv = pd.read_csv(meta_dir + '/mass_case_description_train_set.csv')
test_csv = pd.read_csv(meta_dir + '/mass_case_description_test_set.csv')

# %%
dicom_data.SeriesDescription.value_counts()
# Out:
# cropped images           3567
# ROI mask images          3247
# full mammogram images    2857
# Name: SeriesDescription, dtype: int64

# %%
sns.barplot(x=['Cropped', 'ROI', 'Full'], y=dicom_data.SeriesDescription.value_counts())
# Add ylabel to the plot
plt.ylabel('Number of images')
# Out:
# Text(0, 0.5, 'Number of images')

# %%
train_csv.pathology.value_counts()
# Out:
# MALIGNANT                  637
# BENIGN                     577
# BENIGN_WITHOUT_CALLBACK    104
# Name: pathology, dtype: int64

# %%
# Barplot of 637 and 681
sns.barplot(x=['Malignant', 'Benign'], y=[637, 681])
# Out:
# <AxesSubplot:>

# %%
test_csv.pathology.value_counts()
# Out:
# BENIGN                     194
# MALIGNANT                  147
# BENIGN_WITHOUT_CALLBACK     37
# Name: pathology, dtype: int64

# %%
sns.barplot(x=['Malignant', 'Benign'], y=[147, (194+37)])
# Out:
# <AxesSubplot:>
